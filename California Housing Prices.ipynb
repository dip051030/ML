# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns

# %%
df = pd.read_csv(filepath_or_buffer=r'/home/dip__4/Documents/Datasets/housing.csv')

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.shape
# Out:
# (20640, 10)

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
df.size
# Out:
# 206400

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
df = df.dropna(axis = 0)

# %%
df.shape
# Out:
# (20433, 10)

# %%
df.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
X_features = df.drop(columns=['median_house_value'])
y_target = df['median_house_value']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_features, y_target, test_size=0.25)

# %%
trained_data = X_train.join(y_train)

# %%
trained_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11750    -121.18     38.78                13.0       3480.0           528.0
# 18197    -122.00     37.39                36.0       1236.0           229.0
# 10871    -117.91     33.72                32.0       2436.0           504.0
# 9749     -121.62     36.69                12.0        512.0           144.0
# 6400     -118.05     34.13                23.0       3264.0           729.0
# ...          ...       ...                 ...          ...             ...
# 20359    -118.95     34.17                 9.0       2372.0           312.0
# 13358    -117.61     34.04                 8.0       4116.0           766.0
# 907      -121.99     37.55                28.0       2414.0           415.0
# 2723     -115.50     32.75                13.0        330.0            72.0
# 19112    -122.63     38.22                34.0        878.0           160.0
#
#        population  households  median_income ocean_proximity  \
# 11750      1432.0       532.0         6.1642          INLAND
# 18197       880.0       247.0         5.7910       <1H OCEAN
# 10871      2839.0       516.0         4.5607       <1H OCEAN
# 9749        767.0       149.0         2.2667       <1H OCEAN
# 6400       1475.0       668.0         3.7350          INLAND
# ...           ...         ...            ...             ...
# 20359      1039.0       321.0         7.6016       <1H OCEAN
# 13358      1785.0       745.0         3.1672          INLAND
# 907        1106.0       453.0         4.8403       <1H OCEAN
# 2723        822.0        64.0         3.4107          INLAND
# 19112       372.0       167.0         4.0417       <1H OCEAN
#
#        median_house_value
# 11750            277800.0
# 18197            239400.0
# 10871            182100.0
# 9749              72900.0
# 6400             218300.0
# ...                   ...
# 20359            344900.0
# 13358            150200.0
# 907              268600.0
# 2723             142500.0
# 19112            232100.0
#
# [15324 rows x 10 columns]

# %%
trained_data.hist(figsize=(15, 10))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(trained_data.corr(numeric_only=True), annot=True, cmap='viridis', linecolor='black', linewidths=0.5)
# Out:
# <Axes: >

# %%
trained_data['total_rooms'] = np.log(trained_data['total_rooms'] + 1)
trained_data['total_bedrooms'] = np.log(trained_data['total_bedrooms'] + 1)
trained_data['population'] = np.log(trained_data['population'] + 1)
trained_data['households'] = np.log(trained_data['households'] + 1)

# %%
trained_data.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
trained_data['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     6725
# INLAND        4946
# NEAR OCEAN    1953
# NEAR BAY      1698
# ISLAND           2
# Name: count, dtype: int64

# %%
trained_data = trained_data.join(pd.get_dummies(trained_data['ocean_proximity']) * 1).drop(['ocean_proximity'], axis = 1)

# %%
trained_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11750    -121.18     38.78                13.0     8.155075        6.270988
# 18197    -122.00     37.39                36.0     7.120444        5.438079
# 10871    -117.91     33.72                32.0     7.798523        6.224558
# 9749     -121.62     36.69                12.0     6.240276        4.976734
# 6400     -118.05     34.13                23.0     8.091015        6.593045
# ...          ...       ...                 ...          ...             ...
# 20359    -118.95     34.17                 9.0     7.771910        5.746203
# 13358    -117.61     34.04                 8.0     8.322880        6.642487
# 907      -121.99     37.55                28.0     7.789455        6.030685
# 2723     -115.50     32.75                13.0     5.802118        4.290459
# 19112    -122.63     38.22                34.0     6.778785        5.081404
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 11750    7.267525    6.278521         6.1642            277800.0          0
# 18197    6.781058    5.513429         5.7910            239400.0          1
# 10871    7.951559    6.248043         4.5607            182100.0          1
# 9749     6.643790    5.010635         2.2667             72900.0          1
# 6400     7.297091    6.505784         3.7350            218300.0          0
# ...           ...         ...            ...                 ...        ...
# 20359    6.946976    5.774552         7.6016            344900.0          1
# 13358    7.487734    6.614726         3.1672            150200.0          0
# 907      7.009409    6.118097         4.8403            268600.0          1
# 2723     6.712956    4.174387         3.4107            142500.0          0
# 19112    5.921578    5.123964         4.0417            232100.0          1
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 11750       1       0         0           0
# 18197       0       0         0           0
# 10871       0       0         0           0
# 9749        0       0         0           0
# 6400        1       0         0           0
# ...       ...     ...       ...         ...
# 20359       0       0         0           0
# 13358       1       0         0           0
# 907         0       0         0           0
# 2723        1       0         0           0
# 19112       0       0         0           0
#
# [15324 rows x 14 columns]

# %%
plt.figure(figsize=(14, 12))
sns.heatmap(trained_data.corr(), annot=True, cmap='viridis', linecolor='black', linewidths=0.5)
# Out:
# <Axes: >

# %%
trained_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15324 entries, 11750 to 19112
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           15324 non-null  float64
#  1   latitude            15324 non-null  float64
#  2   housing_median_age  15324 non-null  float64
#  3   total_rooms         15324 non-null  float64
#  4   total_bedrooms      15324 non-null  float64
#  5   population          15324 non-null  float64
#  6   households          15324 non-null  float64
#  7   median_income       15324 non-null  float64
#  8   median_house_value  15324 non-null  float64
#  9   <1H OCEAN           15324 non-null  int64
#  10  INLAND              15324 non-null  int64
#  11  ISLAND              15324 non-null  int64
#  12  NEAR BAY            15324 non-null  int64
#  13  NEAR OCEAN          15324 non-null  int64
# dtypes: float64(9), int64(5)
# memory usage: 2.3 MB

# %%
plt.figure(figsize=(14, 10))
sns.scatterplot(x='latitude', y ='longitude', data = trained_data, hue = 'median_house_value', palette='coolwarm')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
trained_data['bedroom_ratio'] = trained_data['total_bedrooms'] / trained_data['total_rooms']
trained_data['households_rooms'] = trained_data['total_rooms'] / trained_data['households']

# %%
trained_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11750    -121.18     38.78                13.0     8.155075        6.270988
# 18197    -122.00     37.39                36.0     7.120444        5.438079
# 10871    -117.91     33.72                32.0     7.798523        6.224558
# 9749     -121.62     36.69                12.0     6.240276        4.976734
# 6400     -118.05     34.13                23.0     8.091015        6.593045
# ...          ...       ...                 ...          ...             ...
# 20359    -118.95     34.17                 9.0     7.771910        5.746203
# 13358    -117.61     34.04                 8.0     8.322880        6.642487
# 907      -121.99     37.55                28.0     7.789455        6.030685
# 2723     -115.50     32.75                13.0     5.802118        4.290459
# 19112    -122.63     38.22                34.0     6.778785        5.081404
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 11750    7.267525    6.278521         6.1642            277800.0          0
# 18197    6.781058    5.513429         5.7910            239400.0          1
# 10871    7.951559    6.248043         4.5607            182100.0          1
# 9749     6.643790    5.010635         2.2667             72900.0          1
# 6400     7.297091    6.505784         3.7350            218300.0          0
# ...           ...         ...            ...                 ...        ...
# 20359    6.946976    5.774552         7.6016            344900.0          1
# 13358    7.487734    6.614726         3.1672            150200.0          0
# 907      7.009409    6.118097         4.8403            268600.0          1
# 2723     6.712956    4.174387         3.4107            142500.0          0
# 19112    5.921578    5.123964         4.0417            232100.0          1
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  households_rooms
# 11750       1       0         0           0       0.768968          1.298885
# 18197       0       0         0           0       0.763728          1.291473
# 10871       0       0         0           0       0.798171          1.248155
# 9749        0       0         0           0       0.797518          1.245406
# 6400        1       0         0           0       0.814860          1.243665
# ...       ...     ...       ...         ...            ...               ...
# 20359       0       0         0           0       0.739355          1.345890
# 13358       1       0         0           0       0.798100          1.258235
# 907         0       0         0           0       0.774211          1.273183
# 2723        1       0         0           0       0.739464          1.389933
# 19112       0       0         0           0       0.749604          1.322957
#
# [15324 rows x 16 columns]

# %%
plt.figure(figsize=(14, 12))
sns.heatmap(trained_data.corr(), annot=True, linecolor='black', linewidths=0.5, cmap='viridis')
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
trained_data = trained_data.dropna(axis = 0)
X_train, y_train = trained_data.drop(['median_house_value'], axis = 1), trained_data['median_house_value']

X_train_s = scaler.fit_transform(X_train)

reg = LinearRegression()
reg.fit(X_train_s, y_train)
# Out:
# LinearRegression()

# %%
X_train.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# <1H OCEAN             0
# INLAND                0
# ISLAND                0
# NEAR BAY              0
# NEAR OCEAN            0
# bedroom_ratio         0
# households_rooms      0
# dtype: int64

# %%
X_train.shape
# Out:
# (15324, 15)

# %%
reg.score(X_train, y_train)
# Out:
# /home/dip__4/anaconda3/lib/python3.11/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# -2176.946333524269

# %%
test_data = X_test.join(y_test)

test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['households'] = np.log(test_data['households'] + 1)

test_data = test_data.join(pd.get_dummies(test_data['ocean_proximity']) * 1).drop(['ocean_proximity'], axis = 1)

test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data['households_rooms'] = test_data['total_rooms'] / test_data['households']

X_test, y_test = test_data.drop(['median_house_value'], axis = 1), test_data['median_house_value']

# %%
test_data.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# <1H OCEAN             0
# INLAND                0
# ISLAND                0
# NEAR BAY              0
# NEAR OCEAN            0
# bedroom_ratio         0
# households_rooms      0
# dtype: int64

# %%
test_data.shape
# Out:
# (5109, 16)

# %%
trained_data.shape
# Out:
# (15324, 16)

# %%
trained_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15324 entries, 11750 to 19112
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           15324 non-null  float64
#  1   latitude            15324 non-null  float64
#  2   housing_median_age  15324 non-null  float64
#  3   total_rooms         15324 non-null  float64
#  4   total_bedrooms      15324 non-null  float64
#  5   population          15324 non-null  float64
#  6   households          15324 non-null  float64
#  7   median_income       15324 non-null  float64
#  8   median_house_value  15324 non-null  float64
#  9   <1H OCEAN           15324 non-null  int64
#  10  INLAND              15324 non-null  int64
#  11  ISLAND              15324 non-null  int64
#  12  NEAR BAY            15324 non-null  int64
#  13  NEAR OCEAN          15324 non-null  int64
#  14  bedroom_ratio       15324 non-null  float64
#  15  households_rooms    15324 non-null  float64
# dtypes: float64(11), int64(5)
# memory usage: 2.5 MB

# %%
X_test.shape
# Out:
# (5109, 15)

# %%
y_test.shape
# Out:
# (5109,)

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5109 entries, 20602 to 18427
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           5109 non-null   float64
#  1   latitude            5109 non-null   float64
#  2   housing_median_age  5109 non-null   float64
#  3   total_rooms         5109 non-null   float64
#  4   total_bedrooms      5109 non-null   float64
#  5   population          5109 non-null   float64
#  6   households          5109 non-null   float64
#  7   median_income       5109 non-null   float64
#  8   <1H OCEAN           5109 non-null   int64
#  9   INLAND              5109 non-null   int64
#  10  ISLAND              5109 non-null   int64
#  11  NEAR BAY            5109 non-null   int64
#  12  NEAR OCEAN          5109 non-null   int64
#  13  bedroom_ratio       5109 non-null   float64
#  14  households_rooms    5109 non-null   float64
# dtypes: float64(10), int64(5)
# memory usage: 767.7 KB

# %%
y_test.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 5109 entries, 20602 to 18427
# Series name: median_house_value
# Non-Null Count  Dtype
# --------------  -----
# 5109 non-null   float64
# dtypes: float64(1)
# memory usage: 208.9 KB

# %%
X_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11750    -121.18     38.78                13.0     8.155075        6.270988
# 18197    -122.00     37.39                36.0     7.120444        5.438079
# 10871    -117.91     33.72                32.0     7.798523        6.224558
# 9749     -121.62     36.69                12.0     6.240276        4.976734
# 6400     -118.05     34.13                23.0     8.091015        6.593045
# ...          ...       ...                 ...          ...             ...
# 20359    -118.95     34.17                 9.0     7.771910        5.746203
# 13358    -117.61     34.04                 8.0     8.322880        6.642487
# 907      -121.99     37.55                28.0     7.789455        6.030685
# 2723     -115.50     32.75                13.0     5.802118        4.290459
# 19112    -122.63     38.22                34.0     6.778785        5.081404
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 11750    7.267525    6.278521         6.1642          0       1       0
# 18197    6.781058    5.513429         5.7910          1       0       0
# 10871    7.951559    6.248043         4.5607          1       0       0
# 9749     6.643790    5.010635         2.2667          1       0       0
# 6400     7.297091    6.505784         3.7350          0       1       0
# ...           ...         ...            ...        ...     ...     ...
# 20359    6.946976    5.774552         7.6016          1       0       0
# 13358    7.487734    6.614726         3.1672          0       1       0
# 907      7.009409    6.118097         4.8403          1       0       0
# 2723     6.712956    4.174387         3.4107          0       1       0
# 19112    5.921578    5.123964         4.0417          1       0       0
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio  households_rooms
# 11750         0           0       0.768968          1.298885
# 18197         0           0       0.763728          1.291473
# 10871         0           0       0.798171          1.248155
# 9749          0           0       0.797518          1.245406
# 6400          0           0       0.814860          1.243665
# ...         ...         ...            ...               ...
# 20359         0           0       0.739355          1.345890
# 13358         0           0       0.798100          1.258235
# 907           0           0       0.774211          1.273183
# 2723          0           0       0.739464          1.389933
# 19112         0           0       0.749604          1.322957
#
# [15324 rows x 15 columns]

# %%
X_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20602    -121.56     39.13                17.0     7.731053        6.411818
# 20600    -121.57     39.16                18.0     7.398174        5.908083
# 9549     -120.84     37.43                32.0     7.970049        6.257668
# 14014    -117.18     32.75                36.0     7.733246        6.282267
# 5703     -118.26     34.23                43.0     7.264730        5.786897
# ...          ...       ...                 ...          ...             ...
# 14360    -117.22     32.74                41.0     7.871693        6.297109
# 1339     -121.89     38.01                28.0     8.199739        6.622736
# 9330     -122.50     37.96                16.0     4.615121        3.044522
# 11125    -117.91     33.84                35.0     7.126891        5.783825
# 18427    -121.83     37.25                17.0     7.754910        6.458338
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 20602    7.382746    6.333280         1.5085          0       1       0
# 20600    6.646391    5.802118         3.1029          0       1       0
# 9549     7.365813    6.184149         3.7784          0       1       0
# 14014    6.823286    6.276643         2.7222          0       0       0
# 5703     6.729824    5.713733         4.5759          1       0       0
# ...           ...         ...            ...        ...     ...     ...
# 14360    6.980076    6.156979         2.4016          0       0       0
# 1339     7.767687    6.464588         3.0042          0       1       0
# 9330     3.828641    3.258097         6.1359          0       0       0
# 11125    7.380256    5.777652         2.9583          1       0       0
# 18427    7.400621    6.436150         3.1932          1       0       0
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio  households_rooms
# 20602         0           0       0.829359          1.220703
# 20600         0           0       0.798587          1.275082
# 9549          0           0       0.785148          1.288787
# 14014         0           1       0.812371          1.232067
# 5703          0           0       0.796574          1.271451
# ...         ...         ...            ...               ...
# 14360         0           1       0.799969          1.278499
# 1339          0           0       0.807676          1.268409
# 9330          1           0       0.659684          1.416508
# 11125         0           0       0.811550          1.233527
# 18427         0           0       0.832806          1.204899
#
# [5109 rows x 15 columns]

# %%
X_test_s = scaler.transform(X)

# %%
reg.score(X_test_s, y_test)
# Out:
# 0.6600988493046053

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(X_train_s, y_train)

forest.score(X_test_s, y_test)
# Out:
# 0.8123660402783861

# %%
forest.score(X_test_s, y_test)
# Out:
# 0.8123660402783861

# %%
from sklearn.model_selection import GridSearchCV
forest = RandomForestRegressor()

param_grid = {
    'n_estimators': [100, 200, 300],
    # 'max_features': [8, 12, 20],
    'min_samples_split': [2, 4],
    'max_depth': [None, 4, 8]
}

grid_search = GridSearchCV(forest, param_grid, cv = 5, scoring = 'neg_mean_squared_error', return_train_score=True)
grid_search.fit(X_train_s, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [None, 4, 8], 'min_samples_split': [2, 4],
#                          'n_estimators': [100, 200, 300]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_forest = grid_search.best_estimator_

# %%
best_forest.score(X_test_s, y_test)
# Out:
# 0.8140468630502542

# %%
best_forest
# Out:
# RandomForestRegressor(n_estimators=300)
